# %%
import pandas as pd

# %%
try:
    # Try loading the file from your laptop path
    df = pd.read_csv('C:/Users/user/OneDrive/Documents/GitHub/Data-Analysis-Portfolio/bike-sales/Sales.csv')
except FileNotFoundError:
    # If the file is not found, try loading from the PC path
    df = pd.read_csv('C:/Users/Eugene/Documents/GitHub/Data-Analysis-Portfolio/bike-sales/Sales.csv')

# %%
df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
df.describe(include=object)
# Out:
#               Date   Month       Age_Group Customer_Gender        Country  \
# count       113036  113036          113036          113036         113036
# unique        1884      12               4               2              6
# top     2016-03-01    June  Adults (35-64)               M  United States
# freq           288   11234           55824           58312          39206
#
#              State Product_Category     Sub_Category                Product
# count       113036           113036           113036                 113036
# unique          53                3               17                    130
# top     California      Accessories  Tires and Tubes  Water Bottle - 30 oz.
# freq         22450            70120            33870                  10794

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Product Performance Analysis

# %% [markdown]
# - Analysis 1: Top-selling Products by Revenue and Profit (Identify the products that contribute the most to revenue and profit, helping to focus on high-value items)
# - Analysis 2: Revenue by Product Category and Sub-category (Analyze performance across different product categories and sub-categories to determine which areas are thriving)
# - Analysis 3: Low-performing Products (Dogs) (Identify underperforming products that might need to be phased out)

# %% [markdown]
# #### Top-selling Products by Revenue and Profit

# %% [markdown]
# Identify the products that contribute the most to revenue and profit, helping to focus on high-value items

# %%
# Group by product and calculate total revenue and profit
product_performance = df.groupby('Product').agg({
    'Revenue': 'sum',
    'Profit': 'sum',
    'Order_Quantity': 'sum'
}).reset_index()

# %%
# Top 10 products by revenue
top_products_revenue = product_performance.sort_values(by='Revenue', ascending=False).head(10)
top_products_revenue
# Out:
#                     Product  Revenue   Profit  Order_Quantity
# 61         Road-150 Red, 62  3829416  1243755            1191
# 32   Mountain-200 Black, 38  3366248  1310464            1642
# 59         Road-150 Red, 52  3180840  1053260             980
# 60         Road-150 Red, 56  3158805  1009515             990
# 36  Mountain-200 Silver, 42  3081078  1231452            1461
# 35  Mountain-200 Silver, 38  3035442  1165560            1477
# 58         Road-150 Red, 48  2965309   898517             952
# 34   Mountain-200 Black, 46  2769620  1080672            1349
# 33   Mountain-200 Black, 42  2641606  1036542            1282
# 37  Mountain-200 Silver, 46  2376146   921512            1149

# %%
# Top 10 products by profit
top_products_profit = product_performance.sort_values(by='Profit', ascending=False).head(10)
top_products_profit
# Out:
#                      Product  Revenue   Profit  Order_Quantity
# 32    Mountain-200 Black, 38  3366248  1310464            1642
# 61          Road-150 Red, 62  3829416  1243755            1191
# 36   Mountain-200 Silver, 42  3081078  1231452            1461
# 101    Sport-100 Helmet, Red  2019021  1191402           63663
# 35   Mountain-200 Silver, 38  3035442  1165560            1477
# 99   Sport-100 Helmet, Black  1948695  1141330           62105
# 34    Mountain-200 Black, 46  2769620  1080672            1349
# 59          Road-150 Red, 52  3180840  1053260             980
# 100   Sport-100 Helmet, Blue  1775081  1048446           55895
# 33    Mountain-200 Black, 42  2641606  1036542            1282

# %% [markdown]
# #### Revenue by Product Category and Sub-category

# %% [markdown]
# Analyze performance across different product categories and sub-categories to determine which areas are thriving

# %%
# Group by product category and sub-category
category_performance = df.groupby(['Product_Category', 'Sub_Category']).agg({
    'Revenue': 'sum',
    'Profit': 'sum',
    'Order_Quantity': 'sum'
}).reset_index().sort_values(by='Revenue', ascending=False)

# %%
category_performance
# Out:
#    Product_Category       Sub_Category   Revenue    Profit  Order_Quantity
# 9             Bikes         Road Bikes  33363061  10078875           19771
# 8             Bikes     Mountain Bikes  21123526   8160463           11992
# 10            Bikes      Touring Bikes   7295547   2279938            4648
# 5       Accessories            Helmets   5741081   3380203          181606
# 7       Accessories    Tires and Tubes   4670902   2727713          514051
# 13         Clothing            Jerseys   4113742    603568           88125
# 14         Clothing             Shorts   1740710   1034342           27168
# 2       Accessories  Bottles and Cages   1409174    810598          241726
# 4       Accessories            Fenders   1245733    748914           62138
# 6       Accessories    Hydration Packs    990406    572668           19914
# 16         Clothing              Vests    949063    518791           14526
# ...

# %% [markdown]
# #### Low-performing Products

# %% [markdown]
# Identify underperforming products that might need to be phased out

# %%
# Products with lowest revenue (Bottom 10)
low_products_revenue = product_performance.sort_values(by='Revenue').head(10)

# Products with lowest profit margins
product_performance['Profit_Margin'] = product_performance['Profit'] / product_performance['Revenue']
low_profit_margin = product_performance.sort_values(by='Profit_Margin').head(10)

# %%
low_profit_margin
# Out:
#                             Product  Revenue  Profit  Order_Quantity  \
# 96   Short-Sleeve Classic Jersey, M   427299   43713            9133
# 95   Short-Sleeve Classic Jersey, L   503179   64909           10435
# 98  Short-Sleeve Classic Jersey, XL   447126   58878            9244
# 97   Short-Sleeve Classic Jersey, S   559237   74389           11544
# 0                      AWC Logo Cap   549220   78008           67316
# 19      Long-Sleeve Logo Jersey, XL   515629   76767           11549
# 18       Long-Sleeve Logo Jersey, S   493678   79630           10896
# 16       Long-Sleeve Logo Jersey, L   643544  112342           13979
# 17       Long-Sleeve Logo Jersey, M   524050   92940           11345
# 72            Road-350-W Yellow, 44   601328  159464             408
#
#     Profit_Margin
# 96       0.102301
# 95       0.128998
# 98       0.131681
# 97       0.133019
# 0        0.142034
# 19       0.148880
# 18       0.161299
# 16       0.174568
# 17       0.177349
# ...

# %% [markdown]
# ### Customer Demographics and Behavior

# %% [markdown]
# - Analysis 1: Customer Age Group and Revenue (Identify the age groups that generate the most revenue, allowing for targeted marketing efforts)
# - Analysis 2: Gender-based Buying Behavior (Analyze the difference between male and female customers in terms of purchasing patterns)
# - Analysis 3: Average Order Size by Age Group and Gender (Understand if different age groups or genders tend to buy in larger quantities, which can inform inventory decisions)

# %% [markdown]
# #### Customer Age Group and Revenue

# %% [markdown]
# Identify the age groups that generate the most revenue, allowing for targeted marketing efforts

# %%
# Revenue and order quantity by age group
age_group_revenue = df.groupby('Age_Group').agg({
    'Revenue': 'sum',
    'Order_Quantity': 'sum'
}).reset_index().sort_values(by='Revenue', ascending=False)

age_group_revenue
# Out:
#               Age_Group   Revenue  Order_Quantity
# 0        Adults (35-64)  42584153          672417
# 2  Young Adults (25-34)  30655614          446875
# 3           Youth (<25)  11723199          216147
# 1         Seniors (64+)    308042            9877

# %% [markdown]
# #### Gender-based Buying Behavior

# %% [markdown]
# Analyze the difference between male and female customers in terms of purchasing patterns

# %%
# Revenue and quantity breakdown by gender
gender_sales = df.groupby('Customer_Gender').agg({
    'Revenue': 'sum',
    'Order_Quantity': 'sum'
}).reset_index()

gender_sales
# Out:
#   Customer_Gender   Revenue  Order_Quantity
# 0               F  41935599          645733
# 1               M  43335409          699583

# %% [markdown]
# #### Average Order Size by Age Group and Gender

# %% [markdown]
# Understand if different age groups or genders tend to buy in larger quantities, which can inform inventory decisions

# %%
# Calculate average order size by age group
avg_order_size_age = df.groupby('Age_Group')['Order_Quantity'].mean().reset_index()
avg_order_size_age
# Out:
#               Age_Group  Order_Quantity
# 0        Adults (35-64)       12.045303
# 1         Seniors (64+)       13.530137
# 2  Young Adults (25-34)       11.560899
# 3           Youth (<25)       12.124018

# %%
# Calculate average order size by gender
avg_order_size_gender = df.groupby('Customer_Gender')['Order_Quantity'].mean().reset_index()
avg_order_size_gender
# Out:
#   Customer_Gender  Order_Quantity
# 0               F       11.799814
# 1               M       11.997239

# %% [markdown]
# ### Sales Performance by Region and Time

# %% [markdown]
# - Analysis 1: Revenue by Country and State (Understand which countries and states generate the most revenue, highlighting opportunities for market expansion or optimization)
# - Analysis 2: Monthly and Yearly Sales Trends (Analyze sales patterns over time to identify trends, peak seasons, and growth opportunities)
# - Analysis 3: Sales Growth Rate by Region (Identify regions with the highest growth rates, allowing the business to allocate resources effectively)

# %% [markdown]
# #### Revenue by Country and State

# %% [markdown]
# Understand which countries and states generate the most revenue, highlighting opportunities for market expansion or optimization

# %%
# Revenue breakdown by country and state
regional_sales = df.groupby(['Country', 'State']).agg({
    'Revenue': 'sum',
    'Order_Quantity': 'sum'
}).reset_index().sort_values(by='Revenue', ascending=False)

regional_sales
# Out:
#            Country                State   Revenue  Order_Quantity
# 33   United States           California  17672620          269759
# 30  United Kingdom              England  10646196          157218
# 0        Australia      New South Wales   9203495          115932
# 6           Canada     British Columbia   7877890          191556
# 51   United States           Washington   6741510          137947
# 1        Australia           Queensland   5066267           57592
# 4        Australia             Victoria   5054839           66231
# 46   United States               Oregon   3450410           67012
# 27         Germany               Hessen   2073391           26382
# 29         Germany             Saarland   2029545           31084
# 28         Germany  Nordrhein-Westfalen   1804900           29923
# 17          France        Seine (Paris)   1643279           27433
# 26         Germany              Hamburg   1559005           20427
# ...

# %% [markdown]
# #### Monthly and Yearly Sales Trends

# %% [markdown]
# Analyze sales patterns over time to identify trends, peak seasons, and growth opportunities

# %%
# Revenue trend by year and month
monthly_sales = df.groupby(['Year', 'Month']).agg({
    'Revenue': 'sum',
    'Profit' : 'sum'
}).reset_index().sort_values(by=['Year', 'Month'])

monthly_sales
# Out:
#     Year     Month  Revenue   Profit
# 0   2011     April   698782   223601
# 1   2011    August   880037   285831
# 2   2011  December  1132666   369192
# 3   2011  February   637598   207144
# 4   2011   January   675193   212849
# ..   ...       ...      ...      ...
# 57  2016   January  2553065  1007073
# 58  2016      July   499960   254639
# 59  2016      June  3586300  1388652
# 60  2016     March  2608663  1036532
# 61  2016       May  3264343  1287165
#
# [62 rows x 4 columns]

# %%
# Yearly trend comparison
yearly_sales = df.groupby('Year')['Revenue'].sum().reset_index().sort_values(by='Year')

yearly_sales
# Out:
#    Year   Revenue
# 0  2011   8964888
# 1  2012   9175983
# 2  2013  15240037
# 3  2014  14152724
# 4  2015  20023991
# 5  2016  17713385

# %% [markdown]
# #### Sales Growth Rate by Region

# %% [markdown]
# Identify regions with the highest growth rates, allowing the business to allocate resources effectively

# %%
# Calculate growth rate for each country/state
df['Year'] = pd.to_datetime(df['Date']).dt.year
# growth_rate_region = df.groupby(['Country', 'State', 'Year']).agg({
#      'Revenue': 'sum' #,
#     # 'Profit' : 'sum'
# }).pct_change().reset_index().sort_values(by='Revenue', ascending=False)
growth_rate_region = df.groupby(['Country', 'State', 'Year']).agg({
     'Revenue': 'sum' ,
     'Profit' : 'sum'
}).reset_index().sort_values(by='Revenue', ascending=False)
growth_rate_region
# Out:
#             Country       State  Year  Revenue   Profit
# 192   United States  California  2015  4024256  1777620
# 193   United States  California  2016  3660135  1669029
# 190   United States  California  2013  3140474  1431044
# 191   United States  California  2014  2996200  1411598
# 181  United Kingdom     England  2016  2620809  1112162
# ..              ...         ...   ...      ...      ...
# 261   United States     Wyoming  2016       70        0
# 184   United States     Alabama  2015       54       27
# 183   United States     Alabama  2014       54       27
# 185   United States     Alabama  2016       52       26
# 182   United States     Alabama  2013       50       25
#
# [262 rows x 5 columns]

# %% [markdown]
# ### Market Segmentation and Product Classification

# %% [markdown]
# - Analysis 1: Market Segmentation by Customer Age and Gender (Create market segments based on age and gender to see which customer segments contribute the most to sales)
# - Analysis 2: BCG Matrix for Product Categories (Use the BCG matrix to classify product categories into Stars, Cash Cows, Dogs, and Question Marks, which aids in strategic decision-making)
# - Analysis 3: Product Category Market Share and Growth Rate (Measure the market share and growth rate of each product category to determine which products dominate the market)

# %% [markdown]
# #### Market Segmentation by Customer Age and Gender

# %% [markdown]
# Create market segments based on age and gender to see which customer segments contribute the most to sales

# %%
# Segmentation by age and gender
segment_sales = df.groupby(['Age_Group', 'Customer_Gender']).agg({
    'Revenue': 'sum',
    'Order_Quantity': 'sum'
}).reset_index()
segment_sales
# Out:
#               Age_Group Customer_Gender   Revenue  Order_Quantity
# 0        Adults (35-64)               F  21269149          328479
# 1        Adults (35-64)               M  21315004          343938
# 2         Seniors (64+)               F    130050            4506
# 3         Seniors (64+)               M    177992            5371
# 4  Young Adults (25-34)               F  15194242          214441
# 5  Young Adults (25-34)               M  15461372          232434
# 6           Youth (<25)               F   5342158           98307
# 7           Youth (<25)               M   6381041          117840

# %% [markdown]
# #### BCG Matrix for Product Categories

# %% [markdown]
# Use the BCG matrix to classify product categories into Stars, Cash Cows, Dogs, and Question Marks, which aids in strategic decision-making

# %%
# BCG matrix analysis for product categories
total_revenue = df['Revenue'].sum()
category_performance = df.groupby('Product_Category').agg({
    'Revenue': 'sum',
    'Order_Quantity': 'sum'
}).reset_index()

# Market share calculation (as % of total revenue)
category_performance['Market_Share'] = category_performance['Revenue'] / total_revenue

category_performance
# Out:
#   Product_Category   Revenue  Order_Quantity  Market_Share
# 0      Accessories  15117992         1054162      0.177293
# 1            Bikes  61782134           36411      0.724539
# 2         Clothing   8370882          254743      0.098168

# %%
sub_category_performance = df.groupby('Sub_Category').agg({
    'Revenue': 'sum',
    'Order_Quantity': 'sum'
}).reset_index()

# Market share calculation (as % of total revenue)
sub_category_performance['Market_Share'] = sub_category_performance['Revenue'] / total_revenue

sub_category_performance
# Out:
#          Sub_Category   Revenue  Order_Quantity  Market_Share
# 0          Bike Racks    517800            4741      0.006072
# 1         Bike Stands    344075            2412      0.004035
# 2   Bottles and Cages   1409174          241726      0.016526
# 3                Caps    548777           67268      0.006436
# 4            Cleaners    198821           27574      0.002332
# 5             Fenders   1245733           62138      0.014609
# 6              Gloves    871419           39978      0.010219
# 7             Helmets   5741081          181606      0.067327
# 8     Hydration Packs    990406           19914      0.011615
# 9             Jerseys   4113742           88125      0.048243
# 10     Mountain Bikes  21123526           11992      0.247722
# 11         Road Bikes  33363061           19771      0.391259
# 12             Shorts   1740710           27168      0.020414
# 13              Socks    147171           17678      0.001726
# ...

# %% [markdown]
# #### Product Category Market Share and Growth Rate

# %% [markdown]
# Measure the market share and growth rate of each product category to determine which products dominate the market

# %%
# Market share calculation per product category
product_market_share = df.groupby('Product_Category').agg({
    'Revenue': 'sum',
    'Order_Quantity': 'sum'
}).reset_index()

product_market_share
# Out:
#   Product_Category   Revenue  Order_Quantity
# 0      Accessories  15117992         1054162
# 1            Bikes  61782134           36411
# 2         Clothing   8370882          254743

# %%
# Growth rate calculation year-over-year for product categories
category_growth = df.groupby(['Product_Category', 'Year']).agg({
    'Revenue': 'sum'
}).pct_change().reset_index().sort_values(by='Revenue', ascending=False)
category_growth
# Out:
#    Product_Category  Year   Revenue
# 4             Bikes  2011  1.158014
# 8             Bikes  2015  0.944371
# 1       Accessories  2014  0.268711
# 3       Accessories  2016  0.264239
# 13         Clothing  2016  0.127930
# 11         Clothing  2014  0.125613
# 6             Bikes  2013  0.074412
# 5             Bikes  2012  0.023547
# 12         Clothing  2015 -0.137433
# 7             Bikes  2014 -0.227974
# 9             Bikes  2016 -0.231564
# 2       Accessories  2015 -0.234684
# 10         Clothing  2013 -0.824392
# 0       Accessories  2013       NaN

# %%
# Growth rate calculation year-over-year for product categories
category_growth = df.groupby(['Product_Category', 'Year']).agg({
    'Revenue': 'sum'
}).reset_index().sort_values(by='Revenue', ascending=False)
category_growth
# Out:
#    Product_Category  Year   Revenue
# 8             Bikes  2015  14799083
# 9             Bikes  2016  11372150
# 6             Bikes  2013   9858787
# 5             Bikes  2012   9175983
# 4             Bikes  2011   8964888
# 7             Bikes  2014   7611243
# 1       Accessories  2014   4293592
# 3       Accessories  2016   4154231
# 0       Accessories  2013   3384215
# 2       Accessories  2015   3285954
# 11         Clothing  2014   2247889
# 13         Clothing  2016   2187004
# 10         Clothing  2013   1997035
# 12         Clothing  2015   1938954

# %%
# Growth rate calculation year-over-year for product categories
category_growth = df.groupby(['Product_Category', 'Year']).agg({
    'Revenue': 'sum'
}).reset_index().sort_values(by='Product_Category', ascending=False)
category_growth
# Out:
#    Product_Category  Year   Revenue
# 10         Clothing  2013   1997035
# 11         Clothing  2014   2247889
# 12         Clothing  2015   1938954
# 13         Clothing  2016   2187004
# 4             Bikes  2011   8964888
# 5             Bikes  2012   9175983
# 6             Bikes  2013   9858787
# 7             Bikes  2014   7611243
# 8             Bikes  2015  14799083
# 9             Bikes  2016  11372150
# 0       Accessories  2013   3384215
# 1       Accessories  2014   4293592
# 2       Accessories  2015   3285954
# 3       Accessories  2016   4154231

# %% [markdown]
# ### Customer Lifetime Value (CLV) and Retention Analysis

# %% [markdown]
# - Analysis 1: Customer Lifetime Value Calculation (Identify the most valuable customers in terms of revenue generation over time)
# - Analysis 2: Repeat Customer Rate (Understand customer retention by analyzing how many customers make repeat purchases)
# - Analysis 3: Average Revenue Per Customer (ARPU) (Determine the average revenue each customer brings to the business)

# %% [markdown]
# #### Customer Lifetime Value Calculation

# %% [markdown]
# Identify the most valuable customers in terms of revenue generation over time

# %%
# Group by customer to calculate total revenue per customer
clv = df.groupby('Customer_ID').agg({
    'Revenue': 'sum',
    'Order_Quantity': 'sum'
}).reset_index().sort_values(by='Revenue', ascending=False)

clv
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 2
#       1 # Group by customer to calculate total revenue per customer
# ----> 2 clv = df.groupby('Customer_ID').agg({
#       3     'Revenue': 'sum',
#       4     'Order_Quantity': 'sum'
#       5 }).reset_index().sort_values(by='Revenue', ascending=False)
#       7 clv
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:9156, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9153 if level is None and by is None:
#    9154     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9156 return DataFrameGroupBy(
#    9157     obj=self,
#    9158     keys=by,
#    9159     axis=axis,
#    9160     level=level,
#    9161     as_index=as_index,
# ...

# %% [markdown]
# #### Repeat Customer Rate

# %% [markdown]
# Understand customer retention by analyzing how many customers make repeat purchases

# %%
# Repeat customer analysis (customers with more than one purchase)
repeat_customers = df.groupby('Customer_ID')['Order_Quantity'].count().reset_index()
repeat_customers = repeat_customers[repeat_customers['Order_Quantity'] > 1]

# %% [markdown]
# #### Average Revenue Per Customer (ARPU)

# %% [markdown]
# Determine the average revenue each customer brings to the business

# %%
# ARPU calculation
arpu = df.groupby('Country').agg({
    'Revenue': 'sum'
}).reset_index()
arpu['Average_Revenue'] = arpu['Revenue'] / df['Country'].nunique()

arpu
# Out:
#           Country   Revenue  Average_Revenue
# 0       Australia  21302059     3.550343e+06
# 1          Canada   7935738     1.322623e+06
# 2          France   8432872     1.405479e+06
# 3         Germany   8978596     1.496433e+06
# 4  United Kingdom  10646196     1.774366e+06
# 5   United States  27975547     4.662591e+06

# %%
# ARPU calculation
arpu = df.groupby('Year').agg({
    'Revenue': 'sum'
}).reset_index()
arpu['Average_Revenue'] = arpu['Revenue'] / df['Year'].nunique()

arpu
# Out:
#    Year   Revenue  Average_Revenue
# 0  2011   8964888     1.494148e+06
# 1  2012   9175983     1.529330e+06
# 2  2013  15240037     2.540006e+06
# 3  2014  14152724     2.358787e+06
# 4  2015  20023991     3.337332e+06
# 5  2016  17713385     2.952231e+06

# %%
# ARPU calculation
arpu = df.groupby('State').agg({
    'Revenue': 'sum'
}).reset_index()
arpu['Average_Revenue'] = arpu['Revenue'] / df['State'].nunique()

arpu
# Out:
#                   State   Revenue  Average_Revenue
# 0               Alabama       210         3.962264
# 1               Alberta     56803      1071.754717
# 2               Arizona      9379       176.962264
# 3                Bayern   1341985     25320.471698
# 4           Brandenburg    169770      3203.207547
# 5      British Columbia   7877890    148639.433962
# 6            California  17672620    333445.660377
# 7     Charente-Maritime    106047      2000.886792
# 8               England  10646196    200871.622642
# 9               Essonne    973532     18368.528302
# 10              Florida     11014       207.811321
# 11      Garonne (Haute)    183906      3469.924528
# 12              Georgia      4862        91.735849
# 13              Hamburg   1559005     29415.188679
# 14       Hauts de Seine    937140     17681.886792
# 15               Hessen   2073391     39120.584906
# 16             Illinois     20141       380.018868
# ...

# %%
# ARPU calculation
arpu = df.groupby('Customer_Age').agg({
    'Revenue': 'sum'
}).reset_index()
arpu['Average_Revenue'] = arpu['Revenue'] / df['Customer_Age'].nunique()

arpu
# Out:
#     Customer_Age  Revenue  Average_Revenue
# 0             17   726878     10383.971429
# 1             18  1303649     18623.557143
# 2             19  1407281     20104.014286
# 3             20   898471     12835.300000
# 4             21  1238272     17689.600000
# ..           ...      ...              ...
# 65            82     1493        21.328571
# 66            84     5625        80.357143
# 67            85     1405        20.071429
# 68            86     4217        60.242857
# 69            87      552         7.885714
#
# [70 rows x 3 columns]

# %%
# ARPU calculation
arpu = df.groupby('Customer_Age').agg({
    'Revenue': 'sum'
}).reset_index()
arpu['Average_Revenue'] = arpu['Revenue'] / df['Age_Group'].nunique()

arpu
# Out:
#     Customer_Age  Revenue  Average_Revenue
# 0             17   726878        181719.50
# 1             18  1303649        325912.25
# 2             19  1407281        351820.25
# 3             20   898471        224617.75
# 4             21  1238272        309568.00
# ..           ...      ...              ...
# 65            82     1493           373.25
# 66            84     5625          1406.25
# 67            85     1405           351.25
# 68            86     4217          1054.25
# 69            87      552           138.00
#
# [70 rows x 3 columns]

# %% [markdown]
# ### Profitability Analysis

# %% [markdown]
# - Analysis 1: Profit by Product Category and Sub-category (Identify which product categories and sub-categories generate the most profit)
# - Analysis 2: Profit Margins by Product (Calculate profit margins for each product to determine which ones are most efficient in generating profit)
# - Analysis 3: Cost Efficiency by Region (Analyze the cost efficiency of different regions to determine where the business is most profitable)

# %% [markdown]
# #### Profit by Product Category and Sub-category

# %% [markdown]
# Identify which product categories and sub-categories generate the most profit

# %%
# Profit breakdown by product category and sub-category
profitability_category = df.groupby(['Product_Category', 'Sub_Category']).agg({
    'Profit': 'sum'
}).reset_index().sort_values(by='Profit', ascending=False)
profitability_category
# Out:
#    Product_Category       Sub_Category    Profit
# 9             Bikes         Road Bikes  10078875
# 8             Bikes     Mountain Bikes   8160463
# 5       Accessories            Helmets   3380203
# 7       Accessories    Tires and Tubes   2727713
# 10            Bikes      Touring Bikes   2279938
# 14         Clothing             Shorts   1034342
# 2       Accessories  Bottles and Cages    810598
# 4       Accessories            Fenders    748914
# 13         Clothing            Jerseys    603568
# 6       Accessories    Hydration Packs    572668
# 16         Clothing              Vests    518791
# 12         Clothing             Gloves    511654
# 0       Accessories         Bike Racks    304455
# 1       Accessories        Bike Stands    201935
# 3       Accessories           Cleaners    115891
# 15         Clothing              Socks     93171
# 11         Clothing               Caps     77921

# %% [markdown]
# #### Profit Margins by Product

# %% [markdown]
# Calculate profit margins for each product to determine which ones are most efficient in generating profit

# %%
# Profit margin calculation
df['Profit_Margin'] = df['Profit'] / df['Revenue']
profit_margin_by_product = df.groupby('Product').agg({
    'Profit_Margin': 'mean'
}).reset_index().sort_values(by='Profit_Margin', ascending=False)
profit_margin_by_product
# Out:
#                             Product  Profit_Margin
# 56                   Road Tire Tube       0.722138
# 53                  Racing Socks, L       0.630829
# 54                  Racing Socks, M       0.629262
# 55                 Road Bottle Cage       0.625271
# 21                     ML Road Tire       0.597989
# ..                              ...            ...
# 0                      AWC Logo Cap       0.134941
# 98  Short-Sleeve Classic Jersey, XL       0.127554
# 95   Short-Sleeve Classic Jersey, L       0.125274
# 97   Short-Sleeve Classic Jersey, S       0.124321
# 96   Short-Sleeve Classic Jersey, M       0.100587
#
# [130 rows x 2 columns]

# %% [markdown]
# #### Cost Efficiency by Region

# %% [markdown]
# Analyze the cost efficiency of different regions to determine where the business is most profitable

# %%
# Cost efficiency analysis by country and state
regional_cost_efficiency = df.groupby(['Country', 'State']).agg({
    'Cost': 'sum',
    'Revenue': 'sum'
}).reset_index()
regional_cost_efficiency['Cost_Efficiency'] = regional_cost_efficiency['Revenue'] / regional_cost_efficiency['Cost']
regional_cost_efficiency
# Out:
#            Country                State     Cost   Revenue  Cost_Efficiency
# 0        Australia      New South Wales  6069811   9203495         1.516274
# 1        Australia           Queensland  3447109   5066267         1.469715
# 2        Australia      South Australia   972435   1397274         1.436882
# 3        Australia             Tasmania   409861    580184         1.415563
# 4        Australia             Victoria  3626813   5054839         1.393741
# 5           Canada              Alberta    33453     56803         1.697994
# 6           Canada     British Columbia  4184542   7877890         1.882617
# 7           Canada              Ontario      447      1045         2.337808
# 8           France    Charente-Maritime    60047    106047         1.766067
# 9           France              Essonne   579684    973532         1.679418
# 10          France      Garonne (Haute)   110959    183906         1.657423
# ...
